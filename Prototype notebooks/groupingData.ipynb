# %%
import pandas as pd
import os, pathlib, math, warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from import_clean import *
from calculate import *
from itertools import combinations
from tqdm.notebook import tqdm
import geopandas as gpd

# %%
area_size = "utla"
root = pathlib.Path("data")

# %%
region_sizes = {"Country" : "ctry",
                "Region" : "rgn",
                "Upper-Tier Local Authority" : "utla",      #153 in England
                "Lower-Tier Local Authority" : "ltla",      #296 in England
                "Middle-Layer Super Output Area" : "msoa",  #2000-6000 households; 5000-15000 persons
                "Lower-Layer Super Output Area" : "lsoa",   #400-1200 households; 1000-3000 persons
                "Output Area" : "oa"}  
region_sizes_list = list(region_sizes.values())
try:
    if region_sizes_list.index(area_size) > 3:
        date = "21"
    else:
        date = "22"
except ValueError:
    raise ValueError(f"'{area_size}' is not a valid area size")

# %%
df_edu = cleanup_all(import_data(area_size, target_codes=["TS067"]), remove_geography_code=False, remove_geography=False)["TS067"]
df_edu
# Out:
#                 geography geography code  \
# 0              Hartlepool      E06000001
# 1           Middlesbrough      E06000002
# 2    Redcar and Cleveland      E06000003
# 3        Stockton-on-Tees      E06000004
# 4              Darlington      E06000005
# ..                    ...            ...
# 169               Torfaen      W06000020
# 170         Monmouthshire      W06000021
# 171               Newport      W06000022
# 172                 Powys      W06000023
# 173        Merthyr Tydfil      W06000024
#
#      Highest level of qualification: Total: All usual residents aged 16 years and over  \
# 0                                                74686
# 1                                               113939
# 2                                               112342
# 3                                               158010
# 4                                                88107
# ..                                                 ...
# 169                                              75113
# 170                                              78239
# 171                                             127423
# 172                                             112536
# 173                                              47674
#
#      Highest level of qualification: No qualifications  \
# 0                                                17286
# 1                                                27282
# 2                                                24732
# 3                                                29441
# 4                                                16972
# ..                                                 ...
# 169                                              16631
# 170                                              12315
# 171                                              27690
# 172                                              21316
# 173                                              12831
#
#      Highest level of qualification: Level 1 and entry level qualifications  \
# 0                                                 7076
# 1                                                11221
# 2                                                10983
# 3                                                15324
# 4                                                 8276
# ..                                                 ...
# 169                                               7697
# 170                                               6463
# 171                                              11741
# 172                                               9694
# 173                                               4556
#
#      Highest level of qualification: Level 2 qualifications  \
# 0                                                10963
# 1                                                15270
# 2                                                15663
# 3                                                23005
# 4                                                12733
# ..                                                 ...
# 169                                              11458
# 170                                              10589
# 171                                              18188
# 172                                              16747
# 173                                               6911
#
#      Highest level of qualification: Apprenticeship  \
# 0                                              5205
# 1                                              7040
# 2                                              8692
# 3                                             10565
# 4                                              6215
# ..                                              ...
# 169                                            4311
# 170                                            3958
# 171                                            6498
# 172                                            6868
# 173                                            2713
#
#      Highest level of qualification: Level 3 qualifications  \
# 0                                                13776
# 1                                                19976
# 2                                                21300
# 3                                                29004
# 4                                                16141
# ..                                                 ...
# 169                                              12736
# 170                                              12172
# 171                                              19978
# 172                                              19125
# 173                                               7453
#
#      Highest level of qualification: Level 4 qualifications and above  \
# 0                                                18526
# 1                                                30127
# 2                                                28003
# 3                                                46648
# 4                                                25517
# ..                                                 ...
# 169                                              20128
# 170                                              30809
# 171                                              39544
# 172                                              35849
# 173                                              11911
#
#      Highest level of qualification: Other qualifications
# 0                                                 1854
# 1                                                 3023
# 2                                                 2969
# 3                                                 4023
# 4                                                 2253
# ..                                                 ...
# 169                                               2152
# 170                                               1933
# 171                                               3784
# 172                                               2937
# 173                                               1299
#
# [174 rows x 10 columns]

# %%
relevant_columns = [column for column in list(df_edu.columns) if "geography" not in column and "Total" not in column and "Other" not in column and "Apprenticeship" not in column]
relevant_columns
# Out:
# ['Highest level of qualification: No qualifications',
#  'Highest level of qualification: Level 1 and entry level qualifications',
#  'Highest level of qualification: Level 2 qualifications',
#  'Highest level of qualification: Level 3 qualifications',
#  'Highest level of qualification: Level 4 qualifications and above']

# %%
years = [0, 10, 11, 13, 16]
for year, column in zip(years, relevant_columns):
    df_edu[column] *= year
df_edu
# Out:
#                 geography geography code  \
# 0              Hartlepool      E06000001
# 1           Middlesbrough      E06000002
# 2    Redcar and Cleveland      E06000003
# 3        Stockton-on-Tees      E06000004
# 4              Darlington      E06000005
# ..                    ...            ...
# 169               Torfaen      W06000020
# 170         Monmouthshire      W06000021
# 171               Newport      W06000022
# 172                 Powys      W06000023
# 173        Merthyr Tydfil      W06000024
#
#      Highest level of qualification: Total: All usual residents aged 16 years and over  \
# 0                                                74686
# 1                                               113939
# 2                                               112342
# 3                                               158010
# 4                                                88107
# ..                                                 ...
# 169                                              75113
# 170                                              78239
# 171                                             127423
# 172                                             112536
# 173                                              47674
#
#      Highest level of qualification: No qualifications  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 169                                                  0
# 170                                                  0
# 171                                                  0
# 172                                                  0
# 173                                                  0
#
#      Highest level of qualification: Level 1 and entry level qualifications  \
# 0                                                70760
# 1                                               112210
# 2                                               109830
# 3                                               153240
# 4                                                82760
# ..                                                 ...
# 169                                              76970
# 170                                              64630
# 171                                             117410
# 172                                              96940
# 173                                              45560
#
#      Highest level of qualification: Level 2 qualifications  \
# 0                                               120593
# 1                                               167970
# 2                                               172293
# 3                                               253055
# 4                                               140063
# ..                                                 ...
# 169                                             126038
# 170                                             116479
# 171                                             200068
# 172                                             184217
# 173                                              76021
#
#      Highest level of qualification: Apprenticeship  \
# 0                                              5205
# 1                                              7040
# 2                                              8692
# 3                                             10565
# 4                                              6215
# ..                                              ...
# 169                                            4311
# 170                                            3958
# 171                                            6498
# 172                                            6868
# 173                                            2713
#
#      Highest level of qualification: Level 3 qualifications  \
# 0                                               179088
# 1                                               259688
# 2                                               276900
# 3                                               377052
# 4                                               209833
# ..                                                 ...
# 169                                             165568
# 170                                             158236
# 171                                             259714
# 172                                             248625
# 173                                              96889
#
#      Highest level of qualification: Level 4 qualifications and above  \
# 0                                               296416
# 1                                               482032
# 2                                               448048
# 3                                               746368
# 4                                               408272
# ..                                                 ...
# 169                                             322048
# 170                                             492944
# 171                                             632704
# 172                                             573584
# 173                                             190576
#
#      Highest level of qualification: Other qualifications
# 0                                                 1854
# 1                                                 3023
# 2                                                 2969
# 3                                                 4023
# 4                                                 2253
# ..                                                 ...
# 169                                               2152
# 170                                               1933
# 171                                               3784
# 172                                               2937
# 173                                               1299
#
# [174 rows x 10 columns]

# %%
columns_to_subtract = [column for column in list(df_edu.columns) if "Other" in column or "Apprenticeship" in column]
column_to_subtract = df_edu[columns_to_subtract[0]]+df_edu[columns_to_subtract[1]]
total_column = [column for column in list(df_edu.columns) if "Total" in column][0]
df_edu[total_column] -= column_to_subtract
df_edu = df_edu.drop(columns=columns_to_subtract)

# %%
qualification_hours = df_edu[relevant_columns].sum(axis=1)
df_edu["Mean Qualification Years"] = qualification_hours
df_edu = df_edu.drop(columns=relevant_columns)
df_edu["Mean Qualification Years"] /= df_edu[total_column]
df_edu
# Out:
#                 geography geography code  \
# 0              Hartlepool      E06000001
# 1           Middlesbrough      E06000002
# 2    Redcar and Cleveland      E06000003
# 3        Stockton-on-Tees      E06000004
# 4              Darlington      E06000005
# ..                    ...            ...
# 169               Torfaen      W06000020
# 170         Monmouthshire      W06000021
# 171               Newport      W06000022
# 172                 Powys      W06000023
# 173        Merthyr Tydfil      W06000024
#
#      Highest level of qualification: Total: All usual residents aged 16 years and over  \
# 0                                                67627
# 1                                               103876
# 2                                               100681
# 3                                               143422
# 4                                                79639
# ..                                                 ...
# 169                                              68650
# 170                                              72348
# 171                                             117141
# 172                                             102731
# 173                                              43662
#
#      Mean Qualification Years
# 0                    9.860810
# 1                    9.837691
# 2                   10.002592
# 3                   10.665832
# 4                   10.559249
# ..                        ...
# 169                 10.060073
# 170                 11.503967
# 171                 10.328544
# 172                 10.740341
# 173                  9.368467
#
# [174 rows x 4 columns]

# %%
df_edu.to_csv(root/"mean_qualification_years"/f"mqy-{area_size}.csv")

# %%
df_shape = gpd.read_file(root / "shape_data" / f"England_{area_size}_20{date}" / f"england_{area_size}_20{date}.shp")
try:
    df_shape_w = gpd.read_file(root / "shape_data" / f"Wales_{area_size}_20{date}" / f"wales_{area_size}_20{date}.shp")
    w_available = True
except:
    w_available = False
    warnings.warn("Wales data either not installed or not available")
# Out:
# C:\Users\timko\AppData\Local\Temp\ipykernel_18860\971881952.py:7: UserWarning: Wales data either not installed or not available
#   warnings.warn("Wales data either not installed or not available")

# %%
if w_available:
    df_shape = pd.concat([df_shape, df_shape_w], axis=0)
df_merged = df_shape.merge(df_edu, left_on=f"{area_size}{date}cd", right_on="geography code")
# Out:
# Empty DataFrame
# Columns: [label_x, ltla22cd, ltla22nm, ltla22nmw, name_x, geometry_x, label_y, name_y, utla22cd, utla22nm, utla22nmw, geometry_y, geography, geography code, Highest level of qualification: Total: All usual residents aged 16 years and over, Mean Qualification Years]
# Index: []

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))
plt.axis("off")
df_merged.plot(column="Mean Qualification Years", ax=ax, legend=True, cmap="magma")
ax.set_title("Mean years in education")
fig.tight_layout()
